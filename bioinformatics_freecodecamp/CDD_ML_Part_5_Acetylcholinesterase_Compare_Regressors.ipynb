# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 5] Comparing Regressors**
#
# Chanin Nantasenamat
#
# ['Data Professor' YouTube channel](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life data science project that you can include in your data science portfolio. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In Part 5, we will be comparing several ML algorithms for build regression models of acetylcholinesterase inhibitors.

# %% [markdown]
# ## **1. Import libraries**

# %%
! pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.16-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.13/site-packages (from lazypredict) (8.1.8)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.13/site-packages (from lazypredict) (1.6.1)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.13/site-packages (from lazypredict) (2.2.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from lazypredict) (4.67.1)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.13/site-packages (from lazypredict) (1.4.2)
# Collecting lightgbm (from lazypredict)
#   Downloading lightgbm-4.6.0-py3-none-macosx_12_0_arm64.whl.metadata (17 kB)
# Collecting xgboost (from lazypredict)
#   Downloading xgboost-3.1.2-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# Collecting pytest-runner (from lazypredict)
#   Downloading pytest_runner-6.0.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting mlflow>=2.0.0 (from lazypredict)
#   Downloading mlflow-3.6.0-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-skinny==3.6.0 (from mlflow>=2.0.0->lazypredict)
#   Downloading mlflow_skinny-3.6.0-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.6.0 (from mlflow>=2.0.0->lazypredict)
#   Downloading mlflow_tracing-3.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow>=2.0.0->lazypredict)
#   Downloading flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: Flask<4 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow>=2.0.0->lazypredict) (3.1.0)
# Collecting alembic!=1.10.0,<2 (from mlflow>=2.0.0->lazypredict)
#   Downloading alembic-1.17.2-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow>=2.0.0->lazypredict) (44.0.1)
# Collecting docker<8,>=4.0.0 (from mlflow>=2.0.0->lazypredict)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow>=2.0.0->lazypredict)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow>=2.0.0->lazypredict)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting huey<3,>=2.5.0 (from mlflow>=2.0.0->lazypredict)
#   Downloading huey-2.5.4-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: matplotlib<4 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow>=2.0.0->lazypredict) (3.10.0)
# Requirement already satisfied: numpy<3 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow>=2.0.0->lazypredict) (2.1.3)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow>=2.0.0->lazypredict) (19.0.0)
# Requirement already satisfied: scipy<2 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow>=2.0.0->lazypredict) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow>=2.0.0->lazypredict) (2.0.39)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (5.5.1)
# Requirement already satisfied: cloudpickle<4 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (3.0.0)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading databricks_sdk-0.73.0-py3-none-any.whl.metadata (40 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading fastapi-0.122.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (8.5.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (5.29.3)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (2.10.3)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (1.1.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (2.32.3)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (4.15.0)
# Collecting uvicorn<1 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow>=2.0.0->lazypredict)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.13/site-packages (from cryptography<47,>=43.0.0->mlflow>=2.0.0->lazypredict) (1.17.1)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading protobuf-6.33.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/lib/python3.13/site-packages (from docker<8,>=4.0.0->mlflow>=2.0.0->lazypredict) (2.3.0)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: Werkzeug>=3.1 in /opt/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /opt/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /opt/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow>=2.0.0->lazypredict)
#   Downloading graphql_core-3.2.7-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow>=2.0.0->lazypredict)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from graphene<4->mlflow>=2.0.0->lazypredict) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/lib/python3.13/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (3.21.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (1.4.8)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (3.2.0)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict)
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas->lazypredict) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas->lazypredict) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (2.27.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow>=2.0.0->lazypredict) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/anaconda3/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.4.8)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/anaconda3/lib/python3.13/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (4.7.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.13/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (1.3.0)
# Requirement already satisfied: h11>=0.8 in /opt/anaconda3/lib/python3.13/site-packages (from uvicorn<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=1.12->cryptography<47,>=43.0.0->mlflow>=2.0.0->lazypredict) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from Jinja2>=3.1.2->Flask<4->mlflow>=2.0.0->lazypredict) (3.0.2)
# Downloading lazypredict-0.2.16-py2.py3-none-any.whl (14 kB)
# Downloading mlflow-3.6.0-py3-none-any.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 27.9 MB/s eta 0:00:00a 0:00:01
# Downloading mlflow_skinny-3.6.0-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 22.8 MB/s eta 0:00:00
# Downloading mlflow_tracing-3.6.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 27.7 MB/s eta 0:00:00
# Downloading alembic-1.17.2-py3-none-any.whl (248 kB)
# Downloading databricks_sdk-0.73.0-py3-none-any.whl (753 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.9/753.9 kB 17.4 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.122.0-py3-none-any.whl (110 kB)
# Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Downloading google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.7-py3-none-any.whl (207 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading huey-2.5.4-py3-none-any.whl (76 kB)
# Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
# Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
# Downloading protobuf-6.33.1-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading lightgbm-4.6.0-py3-none-macosx_12_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.9 MB/s eta 0:00:00
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading pytest_runner-6.0.1-py3-none-any.whl (7.2 kB)
# Downloading xgboost-3.1.2-py3-none-macosx_12_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 21.1 MB/s eta 0:00:00
# Installing collected packages: huey, uvicorn, sqlparse, rsa, pytest-runner, protobuf, Mako, gunicorn, graphql-core, annotated-doc, xgboost, starlette, opentelemetry-proto, opentelemetry-api, lightgbm, graphql-relay, google-auth, docker, alembic, opentelemetry-semantic-conventions, graphene, Flask-CORS, fastapi, databricks-sdk, opentelemetry-sdk, mlflow-tracing, mlflow-skinny, mlflow, lazypredict
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.3
#     Uninstalling protobuf-5.29.3:
#       Successfully uninstalled protobuf-5.29.3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29/29 [lazypredict] [mlflow]skinny]]dk]
# Successfully installed Flask-CORS-6.0.1 Mako-1.3.10 alembic-1.17.2 annotated-doc-0.0.4 databricks-sdk-0.73.0 docker-7.1.0 fastapi-0.122.0 google-auth-2.43.0 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 gunicorn-23.0.0 huey-2.5.4 lazypredict-0.2.16 lightgbm-4.6.0 mlflow-3.6.0 mlflow-skinny-3.6.0 mlflow-tracing-3.6.0 opentelemetry-api-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 protobuf-6.33.1 pytest-runner-6.0.1 rsa-4.9.1 sqlparse-0.5.3 starlette-0.50.0 uvicorn-0.38.0 xgboost-3.1.2

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# ## **2. Load the data set**

# %% [markdown]
# Not necessary: ! wget https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (4695, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (4695, 137)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000666 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 411
# [LightGBM] [Info] Number of data points in the train set: 3756, number of used features: 137
# [LightGBM] [Info] Start training from score 5.814494
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000559 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 411
# [LightGBM] [Info] Number of data points in the train set: 3756, number of used features: 137
# [LightGBM] [Info] Start training from score 5.814494

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                Adjusted R-Squared           R-Squared  \
# Model
# DecisionTreeRegressor                        0.92                0.93
# ExtraTreeRegressor                           0.92                0.93
# ExtraTreesRegressor                          0.92                0.93
# GaussianProcessRegressor                     0.92                0.93
# XGBRegressor                                 0.90                0.91
# RandomForestRegressor                        0.90                0.90
# BaggingRegressor                             0.88                0.89
# MLPRegressor                                 0.87                0.88
# HistGradientBoostingRegressor                0.79                0.79
# LGBMRegressor                                0.76                0.77
# KNeighborsRegressor                          0.75                0.76
# SVR                                          0.68                0.70
# NuSVR                                        0.67                0.68
# GradientBoostingRegressor                    0.54                0.56
# TransformedTargetRegressor                   0.39                0.42
# LinearRegression                             0.39                0.42
# Ridge                                        0.39                0.42
# LassoLarsIC                                  0.39                0.41
# RidgeCV                                      0.39                0.41
# ElasticNetCV                                 0.39                0.41
# LassoCV                                      0.39                0.41
# LassoLarsCV                                  0.38                0.41
# BayesianRidge                                0.38                0.40
# HuberRegressor                               0.38                0.40
# SGDRegressor                                 0.37                0.40
# LinearSVR                                    0.35                0.38
# PoissonRegressor                             0.33                0.35
# AdaBoostRegressor                            0.30                0.32
# OrthogonalMatchingPursuit                    0.26                0.29
# OrthogonalMatchingPursuitCV                  0.26                0.29
# TweedieRegressor                             0.25                0.27
# GammaRegressor                               0.25                0.27
# LarsCV                                       0.19                0.22
# DummyRegressor                              -0.04                0.00
# ElasticNet                                  -0.04                0.00
# LassoLars                                   -0.04                0.00
# Lasso                                       -0.04                0.00
# QuantileRegressor                           -0.05               -0.01
# PassiveAggressiveRegressor                  -0.14               -0.09
# RANSACRegressor                             -0.68               -0.62
# KernelRidge                                -14.17              -13.61
# Lars                          -444788277918230.31 -428560316779802.12
#
#                                      RMSE  Time Taken
# Model
# DecisionTreeRegressor                0.42        0.05
# ExtraTreeRegressor                   0.42        0.06
# ExtraTreesRegressor                  0.42        2.67
# GaussianProcessRegressor             0.42        1.78
# XGBRegressor                         0.48        0.30
# RandomForestRegressor                0.49        1.91
# BaggingRegressor                     0.52        0.19
# MLPRegressor                         0.54        2.02
# HistGradientBoostingRegressor        0.71        0.33
# LGBMRegressor                        0.75        0.09
# KNeighborsRegressor                  0.76        0.24
# SVR                                  0.86        1.34
# NuSVR                                0.88        1.03
# GradientBoostingRegressor            1.03        0.77
# TransformedTargetRegressor           1.19        0.03
# LinearRegression                     1.19        0.03
# Ridge                                1.19        0.02
# LassoLarsIC                          1.19        0.08
# RidgeCV                              1.19        0.05
# ElasticNetCV                         1.19        1.38
# LassoCV                              1.19        1.34
# LassoLarsCV                          1.20        0.08
# BayesianRidge                        1.20        0.05
# HuberRegressor                       1.20        0.10
# SGDRegressor                         1.21        0.04
# LinearSVR                            1.23        0.40
# PoissonRegressor                     1.25        0.12
# AdaBoostRegressor                    1.28        0.38
# OrthogonalMatchingPursuit            1.31        0.02
# OrthogonalMatchingPursuitCV          1.31        0.04
# TweedieRegressor                     1.32        0.05
# GammaRegressor                       1.32        0.08
# LarsCV                               1.37        0.11
# DummyRegressor                       1.55        0.02
# ElasticNet                           1.55        0.03
# LassoLars                            1.55        0.03
# Lasso                                1.55        0.03
# QuantileRegressor                    1.56        0.59
# PassiveAggressiveRegressor           1.62        0.05
# RANSACRegressor                      1.97        0.28
# KernelRidge                          5.93        0.33
# Lars                          32138656.39        0.05

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
#                                Adjusted R-Squared           R-Squared  \
# Model
# RandomForestRegressor                        0.65                0.70
# XGBRegressor                                 0.65                0.70
# BaggingRegressor                             0.62                0.68
# HistGradientBoostingRegressor                0.61                0.67
# MLPRegressor                                 0.61                0.67
# LGBMRegressor                                0.58                0.64
# KNeighborsRegressor                          0.53                0.59
# SVR                                          0.53                0.59
# NuSVR                                        0.52                0.59
# ExtraTreesRegressor                          0.51                0.58
# DecisionTreeRegressor                        0.50                0.58
# ExtraTreeRegressor                           0.47                0.55
# GradientBoostingRegressor                    0.43                0.51
# RidgeCV                                      0.28                0.38
# Ridge                                        0.27                0.38
# TransformedTargetRegressor                   0.27                0.38
# LinearRegression                             0.27                0.38
# BayesianRidge                                0.27                0.38
# ElasticNetCV                                 0.27                0.38
# LassoLarsIC                                  0.27                0.38
# LassoCV                                      0.27                0.38
# LassoLarsCV                                  0.27                0.38
# HuberRegressor                               0.27                0.37
# SGDRegressor                                 0.25                0.36
# PoissonRegressor                             0.24                0.35
# LinearSVR                                    0.24                0.35
# AdaBoostRegressor                            0.18                0.30
# OrthogonalMatchingPursuit                    0.17                0.29
# OrthogonalMatchingPursuitCV                  0.17                0.29
# GammaRegressor                               0.15                0.28
# TweedieRegressor                             0.15                0.28
# LarsCV                                       0.09                0.23
# DummyRegressor                              -0.17               -0.00
# ElasticNet                                  -0.17               -0.00
# LassoLars                                   -0.17               -0.00
# Lasso                                       -0.17               -0.00
# QuantileRegressor                           -0.19               -0.02
# PassiveAggressiveRegressor                  -0.34               -0.14
# RANSACRegressor                             -0.82               -0.55
# GaussianProcessRegressor                    -5.79               -4.80
# KernelRidge                                -16.24              -13.73
# Lars                          -512744626936510.31 -437855486328512.38
#
#                                      RMSE  Time Taken
# Model
# RandomForestRegressor                0.85        1.87
# XGBRegressor                         0.85        0.30
# BaggingRegressor                     0.88        0.20
# HistGradientBoostingRegressor        0.89        0.30
# MLPRegressor                         0.90        1.91
# LGBMRegressor                        0.93        0.08
# KNeighborsRegressor                  0.99        0.09
# SVR                                  0.99        0.78
# NuSVR                                1.00        0.66
# ExtraTreesRegressor                  1.00        2.76
# DecisionTreeRegressor                1.01        0.05
# ExtraTreeRegressor                   1.04        0.06
# GradientBoostingRegressor            1.09        0.78
# RidgeCV                              1.22        0.04
# Ridge                                1.22        0.01
# TransformedTargetRegressor           1.22        0.03
# LinearRegression                     1.22        0.03
# BayesianRidge                        1.22        0.03
# ElasticNetCV                         1.22        1.37
# LassoLarsIC                          1.22        0.06
# LassoCV                              1.22        1.39
# LassoLarsCV                          1.23        0.08
# HuberRegressor                       1.23        0.14
# SGDRegressor                         1.24        0.04
# PoissonRegressor                     1.25        0.03
# LinearSVR                            1.25        0.39
# AdaBoostRegressor                    1.30        0.37
# OrthogonalMatchingPursuit            1.31        0.01
# OrthogonalMatchingPursuitCV          1.31        0.04
# GammaRegressor                       1.32        0.02
# TweedieRegressor                     1.32        0.02
# LarsCV                               1.37        0.10
# DummyRegressor                       1.55        0.01
# ElasticNet                           1.55        0.03
# LassoLars                            1.55        0.02
# Lasso                                1.55        0.03
# QuantileRegressor                    1.57        0.58
# PassiveAggressiveRegressor           1.66        0.04
# RANSACRegressor                      1.93        0.27
# GaussianProcessRegressor             3.74        1.21
# KernelRidge                          5.96        0.34
# Lars                          32498972.40        0.04

# %% [markdown]
# ## **5. Data visualization of model performance**

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
